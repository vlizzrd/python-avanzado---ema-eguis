# %%
# !pip install gTTS -q

# %%
from gtts import gTTS
import os
from IPython.display import Audio, display
import gtts.lang
print("Librerías importadas correctamente.")
# Out:
# Librerías importadas correctamente.

# %%
texto_acento = "Hola, ¿cómo estás? Nos vemos mañana"
tts_es = gTTS(text=texto_acento, lang='es', tld='es', slow = True)
tts_es.save('acento_espana.mp3')
print("Generado: Español de España")
display(Audio('acento_espana.mp3'))
# Out:
# Generado: Español de España
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
