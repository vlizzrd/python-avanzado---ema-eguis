# %%
# !pip install docxtpl -q

# %%
from docxtpl import DocxTemplate
from docx.shared import Mm, Inches, Pt, RGBColor
import os
from datetime import datetime

# %%
doc = DocxTemplate("plantilla_contrato.docx")

# %%
context = {
    'cliente': 'Juan Perez',
    'dni': '32151646',
    'costo': '2000000',
    'servicio': 'venta de automovil'
    
       
}
doc.render(context)
doc.save("plantilla_contrato2025.docx")
print("Documento 'resultado_basico.docx' generado.")
# Out:
# Documento 'resultado_basico.docx' generado.

# %%
archivo_entrada = "plantilla_contrato2025.docx"
archivo_salida = "plantilla_contrato2025.pdf"

if os.path.exists(archivo_entrada):
    print(f"Convirtiendo {archivo_entrada}...")
    convert(archivo_entrada, archivo_salida)
    
    print(f"¡Conversión completada! Revisa {archivo_salida}")
else:
    print(f"El archivo {archivo_entrada} no existe.")
# Out:
# Convirtiendo plantilla_contrato2025.docx...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4 if os.path.exists(archivo_entrada):
#       5     print(f"Convirtiendo {archivo_entrada}...")
# ----> 6     convert(archivo_entrada, archivo_salida)
#       8     print(f"¡Conversión completada! Revisa {archivo_salida}")
#       9 else:
#
# NameError: name 'convert' is not defined
